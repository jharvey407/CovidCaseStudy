# %% [markdown]
# ## Random Forest
#
# Random Forest is an ensemble of Decision Trees. With a few exceptions, a `RandomForestClassifier` has all the hyperparameters of a `DecisionTreeClassifier` (to control how trees are grown), plus all the hyperparameters of a `BaggingClassifier` to control the ensemble itself.
#
# The Random Forest algorithm introduces extra randomness when growing trees; instead of searching for the very best feature when splitting a node, it searches for the best feature among a random subset of features. This results in a greater tree diversity, which (once again) trades a higher bias for a lower variance, generally yielding an overall better model. The following `BaggingClassifier` is roughly equivalent to the previous `RandomForestClassifier`. Run the cell below to visualize a single estimator from a random forest model, using the Iris dataset to classify the data into the appropriate species.

# %%
from sklearn.datasets import load_iris
import pydotplus

iris = load_iris()

# Model (can also use single decision tree)
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10)

# Train
model.fit(iris.data, iris.target)
# Extract single tree
estimator = model.estimators_[5]

from sklearn.tree import export_graphviz
from io import StringIO
from IPython.display import Image  

# Export as dot file
dot_data = StringIO()

export_graphviz(estimator, out_file=dot_data, 
                feature_names = iris.feature_names,
                class_names = iris.target_names,
                rounded = True, proportion = False, 
                precision = 2, filled = True)

''' # Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])

# Display in jupyter notebook
from IPython.display import Image
Image(filename = 'tree.png') ''';

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# Notice how each split seperates the data into buckets of similar observations. This is a single tree and a relatively simple classification dataset, but the same method is used in a more complex dataset with greater depth to the trees.

# %% [markdown]
# ## Coronavirus
# Coronavirus disease (COVID-19) is an infectious disease caused by a new virus.
# The disease causes respiratory illness (like the flu) with symptoms such as a cough, fever, and in more severe cases, difficulty breathing. You can protect yourself by washing your hands frequently, avoiding touching your face, and avoiding close contact (1 meter or 3 feet) with people who are unwell. An outbreak of COVID-19 started in December 2019 and at the time of the creation of this project was continuing to spread throughout the world. Many governments recommended only essential outings to public places and closed most business that do not serve food or sell essential items. An excellent [spatial dashboard](https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6) built by Johns Hopkins shows the daily confirmed cases by country.
#
# This case study was designed to drive home the important role that data science plays in real-world situations like this pandemic. This case study uses the Random Forest Classifier and a dataset from the South Korean cases of COVID-19 provided on [Kaggle](https://www.kaggle.com/kimjihoo/coronavirusdataset) to encourage research on this important topic. The goal of the case study is to build a Random Forest Classifier to predict the 'state' of the patient.

# %% [markdown]
# First, please load the needed packages and modules into Python. Next, load the data into a pandas dataframe for ease of use.

# %%
import os
import pandas as pd
from datetime import datetime,timedelta
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import plotly.graph_objects as go
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor

# %%
url ='SouthKoreacoronavirusdataset/PatientInfo.csv'
patient_info = pd.read_csv(url)
df = patient_info
df.sample(10)
# Out:
#       patient_id  global_num     sex  birth_year  age country  \
# 1997  6020000010         NaN  female         NaN  50s   Korea
# 2177  6106000049         NaN  female      1956.0  60s   Korea
# 1730  6008000005         NaN     NaN         NaN  NaN   Korea
# 126   1000000127      7280.0    male      1969.0  50s   Korea
# 1624  6002000015         NaN    male      1958.0  60s   Korea
# 1502  6001000428      6342.0  female      1968.0  50s   Korea
# 74    1000000075      3007.0    male      1982.0  30s   Korea
# 851   2000000263      8411.0  female      1980.0  NaN   Korea
# 787   2000000199      8009.0    male      1971.0  NaN   Korea
# 1751  6008000026         NaN     NaN         NaN  NaN   Korea
#
#               province          city disease        infection_case  \
# 1997  Gyeongsangbuk-do  Cheongdo-gun     NaN                   NaN
# 2177  Gyeongsangnam-do    Miryang-si     NaN                   NaN
# 1730  Gyeongsangbuk-do   Bonghwa-gun     NaN                   NaN
# ...

# %%
df.shape
# Out:
# (2218, 18)

# %%
#Counts of null values 
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']>0)]
# Out:
#                VarName  NullCount
# 0              disease       2199
# 1        deceased_date       2186
# 2      infection_order       2176
# 3   symptom_onset_date       2025
# 4        released_date       1995
# 5       contact_number       1807
# 6          infected_by       1749
# 7       infection_case       1055
# 8           global_num        904
# 9           birth_year        454
# 10                 age        261
# 11                 sex        145
# 12      confirmed_date        141
# 13               state         88
# 14                city         65

# %%
#counts of response variable values
df.state.value_counts()
# Out:
# isolated    1791
# released     307
# deceased      32
# Name: state, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2218 entries, 0 to 2217
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          2218 non-null   int64
#  1   global_num          1314 non-null   float64
#  2   sex                 2073 non-null   object
#  3   birth_year          1764 non-null   float64
#  4   age                 1957 non-null   object
#  5   country             2218 non-null   object
#  6   province            2218 non-null   object
#  7   city                2153 non-null   object
#  8   disease             19 non-null     object
#  9   infection_case      1163 non-null   object
#  10  infection_order     42 non-null     float64
#  11  infected_by         469 non-null    float64
#  12  contact_number      411 non-null    float64
#  13  symptom_onset_date  193 non-null    object
#  14  confirmed_date      2077 non-null   object
# ...

# %% [markdown]
#  **<font color='teal'> Create a new column named 'n_age' which is the calculated age based on the birth year column.</font>**

# %%
# Test convert Float to date time year
from datetime import datetime
from datetime import date

def calc_age(birth_year): # birth_year will be float from column 'birth_year'
    birth_year = pd.to_datetime(birth_year, format='%Y').year
    today = date.today().year
    return today - birth_year
    
df['n_age'] = df['birth_year'].apply(calc_age)
df['n_age'].sample(5)
# Out:
# 791     61.0
# 1150    23.0
# 2046    65.0
# 1464    70.0
# 1758     NaN
# Name: n_age, dtype: float64

# %% [markdown]
# ### Handle Missing Values

# %% [markdown]
#  **<font color='teal'> Print the number of missing values by column.</font>**

# %%
#Counts of null values 
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']>0)]
# Out:
#                VarName  NullCount
# 0              disease       2199
# 1        deceased_date       2186
# 2      infection_order       2176
# 3   symptom_onset_date       2025
# 4        released_date       1995
# 5       contact_number       1807
# 6          infected_by       1749
# 7       infection_case       1055
# 8           global_num        904
# 9           birth_year        454
# 10               n_age        454
# 11                 age        261
# 12                 sex        145
# 13      confirmed_date        141
# 14               state         88
# 15                city         65

# %% [markdown]
#  **<font color='teal'> Fill the 'disease' missing values with 0 and remap the True values to 1.</font>**

# %%
df['disease'] = df['disease'].fillna(0)
df['disease'] = df['disease'].replace(True, 1)
df['disease'].value_counts()
# Out:
# 0    2199
# 1      19
# Name: disease, dtype: int64

# %% [markdown]
#  **<font color='teal'> Fill null values in the following columns with their mean: 'global_number','birth_year','infection_order','infected_by'and 'contact_number'</font>**

# %%
values = {'global_num': df.global_num.mean(), 'birth_year': df.birth_year.mean(), 
          'infection_order': df.infection_order.mean(), 'contact_number': df.contact_number.mean()}
df = df.fillna(value=values)

# %% [markdown]
#  **<font color='teal'> Remove date columns from the data.</font>**

# %%
df = df.drop(['symptom_onset_date','confirmed_date','released_date','deceased_date'],axis =1)

# %% [markdown]
#  **<font color='teal'> Fill the rest of the missing values with any method.</font>**

# %%
#Counts of null values 
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']>0)]
# Out:
#           VarName  NullCount
# 0     infected_by       1749
# 1  infection_case       1055
# 2           n_age        454
# 3             age        261
# 4             sex        145
# 5           state         88
# 6            city         65

# %%
df.dtypes
# Out:
# patient_id           int64
# global_num         float64
# sex                 object
# birth_year         float64
# age                 object
# country             object
# province            object
# city                object
# disease              int64
# infection_case      object
# infection_order    float64
# infected_by        float64
# contact_number     float64
# state               object
# n_age              float64
# dtype: object

# %%
values = {'infected_by': 0, 'infection_case':'unknown', 'n_age':0, 'age':0, 
          'sex':'unknown', 'state':'unknown', 'city':'unknown' }
df = df.fillna(value=values)

# %% [markdown]
#  **<font color='teal'> Check for any remaining null values.</font>**

# %%
#Counts of null values 
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']==0)]
# Out:
#             VarName  NullCount
# 0             n_age          0
# 1             state          0
# 2    contact_number          0
# 3       infected_by          0
# 4   infection_order          0
# 5    infection_case          0
# 6           disease          0
# 7              city          0
# 8          province          0
# 9           country          0
# 10              age          0
# 11       birth_year          0
# 12              sex          0
# 13       global_num          0
# 14       patient_id          0

# %% [markdown]
# Review the count of unique values by column.

# %%
print(df.nunique())
# Out:
# patient_id         2218
# global_num         1304
# sex                   3
# birth_year           97
# age                  12
# country               4
# province             17
# city                135
# disease               2
# infection_case       17
# infection_order       7
# infected_by         207
# contact_number       73
# state                 4
# n_age                96
# dtype: int64

# %% [markdown]
# Review the percent of unique values by column.

# %%
print(df.nunique()/df.shape[0])
# Out:
# patient_id         1.000000
# global_num         0.587917
# sex                0.001353
# birth_year         0.043733
# age                0.005410
# country            0.001803
# province           0.007665
# city               0.060866
# disease            0.000902
# infection_case     0.007665
# infection_order    0.003156
# infected_by        0.093327
# contact_number     0.032913
# state              0.001803
# n_age              0.043282
# dtype: float64

# %% [markdown]
# Review the range of values per column.

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# patient_id       2218.0  4.014678e+09  2.192419e+09  1.000000e+09
# global_num       2218.0  4.664817e+03  2.211785e+03  1.000000e+00
# birth_year       2218.0  1.974989e+03  1.731123e+01  1.916000e+03
# disease          2218.0  8.566276e-03  9.217769e-02  0.000000e+00
# infection_order  2218.0  2.285714e+00  1.706622e-01  1.000000e+00
# infected_by      2218.0  5.499414e+08  1.284176e+09  0.000000e+00
# contact_number   2218.0  2.412895e+01  3.917141e+01  0.000000e+00
# n_age            2218.0  3.579802e+01  2.509275e+01  0.000000e+00
#
#                           25%           50%           75%           max
# patient_id       1.700000e+09  6.001000e+09  6.004000e+09  7.000000e+09
# global_num       4.205250e+03  4.664817e+03  5.900250e+03  8.717000e+03
# birth_year       1.965000e+03  1.974989e+03  1.988000e+03  2.020000e+03
# disease          0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# ### Check for duplicated rows

# %%
duplicateRowsDF = df[df.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, birth_year, age, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, state, n_age]
# Index: []

# %% [markdown]
# Print the categorical columns and their associated levels.

# %%
dfo = df.select_dtypes(include=['object'], exclude=['datetime'])
dfo.shape
#get levels for all variables
vn = pd.DataFrame(dfo.nunique()).reset_index()
vn.columns = ['VarName', 'LevelsCount']
vn.sort_values(by='LevelsCount', ascending =False)
vn
# Out:
#           VarName  LevelsCount
# 0             sex            3
# 1             age           12
# 2         country            4
# 3        province           17
# 4            city          135
# 5  infection_case           17
# 6           state            4

# %%
df.columns
# Out:
# Index(['patient_id', 'global_num', 'sex', 'birth_year', 'age', 'country',
#        'province', 'city', 'disease', 'infection_case', 'infection_order',
#        'infected_by', 'contact_number', 'state', 'n_age'],
#       dtype='object')

# %% [markdown]
# # Clean Data and
# # Remove uneeded features
# # EDA of features in order

# %%
df2 = pd.DataFrame(df[['sex', 'birth_year', 'age', 'country',
       'province', 'city', 'disease', 'infection_case',
       'contact_number', 'state', 'n_age']])

# %% [markdown]
# ### Print sample of features

# %%
df2.sample(10)
# Out:
#          sex   birth_year  age country           province          city  \
# 579     male  1974.988662  50s   Korea             Sejong        Sejong
# 2015    male  1974.988662  60s   Korea   Gyeongsangbuk-do  Cheongdo-gun
# 1267    male  1990.000000  30s   Korea   Gyeongsangbuk-do  Gyeongsan-si
# 1797    male  2017.000000   0s   Korea   Gyeongsangbuk-do     Sangju-si
# 1309  female  1995.000000  20s   Korea   Gyeongsangbuk-do  Gyeongsan-si
# 280   female  1982.000000  30s   Korea              Seoul    Dongjak-gu
# 1431  female  1946.000000  70s   Korea   Gyeongsangbuk-do  Gyeongsan-si
# 2019  female  1974.988662  80s   Korea   Gyeongsangbuk-do  Cheongdo-gun
# 1153  female  1981.000000  30s   Korea   Gyeongsangbuk-do  Gyeongsan-si
# 998   female  1959.000000  60s   Korea  Chungcheongnam-do    Cheonan-si
#
#       disease                    infection_case  contact_number     state  \
# 579         0  Ministry of Oceans and Fisheries       25.000000  isolated
# ...

# %% [markdown]
# ### Explore the number of unique values to check for unusual amounts

# %%
print(df2.nunique())
# Out:
# sex                 3
# birth_year         97
# age                12
# country             4
# province           17
# city              135
# disease             2
# infection_case     17
# contact_number     73
# state               4
# n_age              96
# dtype: int64

# %% [markdown]
# # Sex

# %%
plt.hist(df2['sex'], bins=3);

# %% [markdown]
# # Birth Year

# %% [markdown]
# #### Use Describe check for outliers

# %%
df2['birth_year'].describe()
# Out:
# count    2218.000000
# mean     1974.988662
# std        17.311232
# min      1916.000000
# 25%      1965.000000
# 50%      1974.988662
# 75%      1988.000000
# max      2020.000000
# Name: birth_year, dtype: float64

# %% [markdown]
# ### Convert birth year to integer

# %%
df2.birth_year = df2.birth_year.astype(int)
df2.birth_year.sample(5)
# Out:
# 1379    1965
# 1071    1974
# 1070    1994
# 768     1971
# 2107    1974
# Name: birth_year, dtype: int32

# %%
df2.birth_year.value_counts()
# Out:
# 1974    483
# 1969     54
# 1995     51
# 1998     47
# 1996     45
#        ...
# 1927      2
# 2011      2
# 1925      1
# 1931      1
# 1916      1
# Name: birth_year, Length: 96, dtype: int64

# %% [markdown]
# #### Plot Histogram

# %%
plt.hist(df2['birth_year']);

# %% [markdown]
# The unusually tall center is due to using the mean of the birth year to fill missing data.
# There are only 12 unique values in the age category.

# %% [markdown]
# # Age

# %% [markdown]
# ### Plot a bar chart of age counts

# %%
df2.age.value_counts()
# Out:
# 20s     467
# 50s     385
# 40s     303
# 0       261
# 30s     251
# 60s     229
# 70s     117
# 80s      84
# 10s      74
# 0s       29
# 90s      17
# 100s      1
# Name: age, dtype: int64

# %%
pd.Series(df2.age.value_counts(ascending=False).plot(kind='bar'));

# %% [markdown]
# # Country

# %%
pd.Series(df2.country.value_counts().plot(kind='bar'));

# %% [markdown]
# The majority of cases are from Korea. The graph is hard to read so we will clarify with actual value counts.

# %%
df2.country.value_counts()
# Out:
# Korea       2206
# China         10
# Mongolia       1
# Thailand       1
# Name: country, dtype: int64

# %%
df2 = df2.drop(['country'], axis=1)

# %% [markdown]
# With the majority of cases being from Korea there is no significance to the Country values so we will drop it as a feature.

# %% [markdown]
# # Province

# %%
df2.province.value_counts()
# Out:
# Gyeongsangbuk-do     1054
# Gyeonggi-do           300
# Seoul                 282
# Chungcheongnam-do     118
# Busan                 101
# Gyeongsangnam-do       85
# Daegu                  63
# Sejong                 41
# Incheon                32
# Ulsan                  30
# Gangwon-do             29
# Chungcheongbuk-do      28
# Daejeon                22
# Gwangju                18
# Jeollabuk-do            7
# Jeju-do                 4
# Jeollanam-do            4
# Name: province, dtype: int64

# %%
pd.Series(df2.province.value_counts().plot(kind='bar'));

# %% [markdown]
# # City

# %%
df2.city.value_counts()
# Out:
# Gyeongsan-si    535
# Cheonan-si       98
# Seongnam-si      89
# unknown          65
# Bonghwa-gun      60
#                ...
# Dalseong-gun      1
# Wuhan             1
# Hamyang-gun       1
# Samcheok-si       1
# Hanam-si          1
# Name: city, Length: 135, dtype: int64

# %%
plt.figure(figsize=(20,5))
pd.Series(df2.city.value_counts().plot(kind='bar'));

# %% [markdown]
# It's hard to judge the significance of the City feature. We'll re-evalutae once we calculate covariance.

# %% [markdown]
# # Disease
# Disease is our predicted value.

# %%
df2.disease.value_counts()
# Out:
# 0    2199
# 1      19
# Name: disease, dtype: int64

# %% [markdown]
# Out of our entire data set, only 19 subjects are positive.

# %% [markdown]
# # Infection Case

# %%
df2.infection_case.value_counts()
# Out:
# unknown                             1055
# contact with patient                 530
# etc                                  220
# Guro-gu Call Center                  102
# Shincheonji Church                    86
# overseas inflow                       61
# Onchun Church                         33
# gym facility in Cheonan               30
# Ministry of Oceans and Fisheries      27
# Cheongdo Daenam Hospital              21
# Dongan Church                         17
# Eunpyeong St. Mary's Hospital         14
# Seongdong-gu APT                      13
# gym facility in Sejong                 4
# Suyeong-gu Kindergarten                3
# Pilgrimage to Israel                   1
# River of Grace Community Church        1
# Name: infection_case, dtype: int64

# %% [markdown]
# Almost half, 47% of our cases do not inicate how the disease was transmitted.

# %%
df2.contact_number.value_counts()
# Out:
# 24.128954      1807
# 0.000000         47
# 2.000000         44
# 3.000000         42
# 1.000000         34
#                ...
# 117.000000        1
# 1160.000000       1
# 84.000000         1
# 174.000000        1
# 75.000000         1
# Name: contact_number, Length: 73, dtype: int64

# %%
plt.hist(df2["contact_number"]);

# %% [markdown]
# The majority of the contact number amounts is 24, which is the mean. We'll re-evaluate when we calculate covariance.

# %% [markdown]
# # State

# %%
df2.state.value_counts()
# Out:
# isolated    1791
# released     307
# unknown       88
# deceased      32
# Name: state, dtype: int64

# %%
pd.Series(df2.state.value_counts().plot(kind='bar'));

# %% [markdown]
# # N Age (calculated from birth year)

# %%
df2.n_age.value_counts()
# Out:
# 0.0      456
# 51.0      54
# 25.0      51
# 22.0      47
# 24.0      45
#         ...
# 9.0        2
# 93.0       2
# 89.0       1
# 95.0       1
# 104.0      1
# Name: n_age, Length: 96, dtype: int64

# %%
plt.figure(figsize=(15,5))
pd.Series(df2.n_age.value_counts(ascending=False).plot(kind='bar'));

# %% [markdown]
# ## Combining the age columns and replacing 0 values with mean
# We have 2 age columns, one is a decade value with entries such as 40s or 20s, the other is a calculated age value calculated from the birth year.
# We are going to combine these two columns. Our primary column will be calculated age. For any 0 value in calculated age, we will take the string from the age column, strip the s from the end and convert the 0 to a 5, transforming the entris from string such as 20s, to an interger such as 25.

# %% [markdown]
# #### Check format of age column

# %%
df2.age.value_counts()
# Out:
# 20s     467
# 50s     385
# 40s     303
# 0       261
# 30s     251
# 60s     229
# 70s     117
# 80s      84
# 10s      74
# 0s       29
# 90s      17
# 100s      1
# Name: age, dtype: int64

# %% [markdown]
# Age is of the type string and has a following S.
# We are going to remove the S and convert the type to integer

# %%
df2.age = df2.age.str.replace('0s', '0')
df2.age = df2.age.fillna(0)
df2.age.value_counts()
# Out:
# 20     467
# 50     385
# 40     303
# 0      261
# 30     251
# 60     229
# 70     117
# 80      84
# 10      74
# 0       29
# 90      17
# 100      1
# Name: age, dtype: int64

# %% [markdown]
# #### Check for null values

# %%
df2.age.isna().sum()
# Out:
# 0

# %% [markdown]
# #### Convert to integers

# %%
df2.age = df2.age.astype(int)

# %% [markdown]
# #### Compare the number of values in the columns __age__ and __n_age__.

# %%
df2.age.value_counts()
# Out:
# 20     467
# 50     385
# 40     303
# 0      290
# 30     251
# 60     229
# 70     117
# 80      84
# 10      74
# 90      17
# 100      1
# Name: age, dtype: int64

# %%
df2.n_age.value_counts()
# Out:
# 0.0      456
# 51.0      54
# 25.0      51
# 22.0      47
# 24.0      45
#         ...
# 9.0        2
# 93.0       2
# 89.0       1
# 95.0       1
# 104.0      1
# Name: n_age, Length: 96, dtype: int64

# %% [markdown]
# #### Combine the columns
# We are going to use the calculated age if it exists, if not we are going to pull the value from the age column to replace the 0 value in the  n_age column.

# %%
df2.loc[df2['n_age'] == 0, 'n_age'] = df2['age']
df2.n_age = df2.n_age.astype(int)

# %% [markdown]
# #### Check the value count to see how many 0 values remain.

# %%
df2.n_age.value_counts()
# Out:
# 0      156
# 20     120
# 50      86
# 40      74
# 60      67
#       ...
# 92       2
# 9        2
# 95       1
# 89       1
# 104      1
# Name: n_age, Length: 96, dtype: int64

# %%
plt.hist(df2['n_age']);

# %% [markdown]
# ### Replace 0 age values with mean age value

# %%
df2['n_age'] = df2['n_age'].replace(0, df2['n_age'].mean())

# %%
plt.hist(df2['n_age']);

# %% [markdown]
# #### Drop the age column.

# %%
df2 = df2.drop(['age'], axis=1)

# %% [markdown]
# #### Drop the birth year column

# %%
df2 = df2.drop('birth_year', axis=1)

# %% [markdown]
# #### Take a last look at our values

# %%
df2.sample(10)
# Out:
#           sex           province          city  disease        infection_case  \
# 430    female              Daegu       unknown        0               unknown
# 1044   female  Chungcheongnam-do    Cheonan-si        0                   etc
# 1775  unknown   Gyeongsangbuk-do   Bonghwa-gun        0               unknown
# 387    female              Daegu        Nam-gu        0    Shincheonji Church
# 774      male        Gyeonggi-do   Seongnam-si        0  contact with patient
# 886    female        Gyeonggi-do  Namyangju-si        0  contact with patient
# 791    female        Gyeonggi-do    Bucheon-si        0  contact with patient
# 882      male        Gyeonggi-do   Hwaseong-si        0       overseas inflow
# 1239   female   Gyeongsangbuk-do  Gyeongsan-si        0               unknown
# 532      male              Ulsan        Nam-gu        0                   etc
#
#       contact_number     state     n_age
# 430        24.128954  deceased  77.00000
# ...

# %%
df2.describe().T
# Out:
#                  count       mean        std  min        25%        50%  \
# disease         2218.0   0.008566   0.092178  0.0   0.000000   0.000000
# contact_number  2218.0  24.128954  39.171414  0.0  24.128954  24.128954
# n_age           2218.0  44.092148  18.671106  1.0  28.000000  41.194770
#
#                       75%     max
# disease          0.000000     1.0
# contact_number  24.128954  1160.0
# n_age           57.000000   104.0

# %% [markdown]
# **<font color='teal'> Print a covariance heatmap. </font>**

# %%
from dython import nominal
nominal.associations(df2, figsize=(15,15));

# %% [markdown]
# #### Our important features seem to be:
#
# State: 0.77
# City: 0.42
# Infection Case: 0.35
# Province: 0.28
# Age: 0.11
# Sex: 0.06
# Contact Number: 0.0

# %% [markdown]
# **<font color='teal'> Create dummy features for object type features. </font>**

# %%
df2.head()
# Out:
#       sex province         city  disease        infection_case  \
# 0    male    Seoul   Gangseo-gu        0       overseas inflow
# 1    male    Seoul  Jungnang-gu        0       overseas inflow
# 2    male    Seoul    Jongno-gu        0  contact with patient
# 3    male    Seoul      Mapo-gu        0       overseas inflow
# 4  female    Seoul  Seongbuk-gu        0  contact with patient
#
#    contact_number     state  n_age
# 0            75.0  released   56.0
# 1            31.0  released   33.0
# 2            17.0  released   56.0
# 3             9.0  released   29.0
# 4             2.0  released   28.0

# %%
df3 = pd.get_dummies(df2)

# %%
df3.head()
# Out:
#    disease  contact_number  n_age  sex_female  sex_male  sex_unknown  \
# 0        0            75.0   56.0           0         1            0
# 1        0            31.0   33.0           0         1            0
# 2        0            17.0   56.0           0         1            0
# 3        0             9.0   29.0           0         1            0
# 4        0             2.0   28.0           1         0            0
#
#    province_Busan  province_Chungcheongbuk-do  province_Chungcheongnam-do  \
# 0               0                           0                           0
# 1               0                           0                           0
# 2               0                           0                           0
# 3               0                           0                           0
# 4               0                           0                           0
#
#    province_Daegu  ...  infection_case_contact with patient  \
# ...

# %% [markdown]
# ### Split the data into test and train subsamples

# %%
from sklearn.model_selection import train_test_split

# dont forget to define your X and y

X = df3.drop(['disease'], axis=1)
y = df3['disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=1)

# %% [markdown]
# ### Scale data to prep for model creation

# %%
#scale data
from sklearn import preprocessing
import numpy as np
# build scaler based on training data and apply it to test data to then also scale the test data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,roc_auc_score
from sklearn.metrics import accuracy_score,log_loss
from matplotlib import pyplot

# %% [markdown]
# ### Fit Random Forest Classifier
# The fit model shows an overall accuracy of 80% which is great and indicates our model was effectively able to identify the status of a patients in the South Korea dataset.

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=300, random_state = 1,n_jobs=-1)
model_res = clf.fit(X_train_scaled, y_train)
y_pred = model_res.predict(X_test_scaled)
y_pred_prob = model_res.predict_proba(X_test_scaled)
lr_probs = y_pred_prob[:,1]
ac = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')
cm = confusion_matrix(y_test, y_pred)

print('Random Forest: Accuracy=%.3f' % (ac))

print('Random Forest: f1-score=%.3f' % (f1))
# Out:
# Random Forest: Accuracy=0.984
# Random Forest: f1-score=0.983

# %% [markdown]
# ### Create Confusion Matrix Plots
# Confusion matrices are great ways to review your model performance for a multi-class classification problem. Being able to identify which class the misclassified observations end up in is a great way to determine if you need to build additional features to improve your overall model. In the example below we plot a regular counts confusion matrix as well as a weighted percent confusion matrix. The percent confusion matrix is particulary helpful when you have unbalanced class sizes.

# %%
class_names=['isolated','released','missing','deceased'] # name  of classes

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
#plt.savefig('figures/RF_cm_multi_class.png')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
#plt.savefig('figures/RF_cm_proportion_multi_class.png', bbox_inches="tight")
plt.show()
# Out:
# Confusion matrix, without normalization
# [[437   3]
#  [  4   0]]
# Normalized confusion matrix
# [[0.99 0.01]
#  [1.   0.  ]]

# %% [markdown]
# ### Plot feature importances
# The random forest algorithm can be used as a regression or classification model. In either case it tends to be a bit of a black box, where understanding what's happening under the hood can be difficult. Plotting the feature importances is one way that you can gain a perspective on which features are driving the model predictions.

# %%
feature_importance = clf.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(10,10))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# 30

# %% [markdown]
# The popularity of random forest is primarily due to how well it performs in a multitude of data situations. It tends to handle highly correlated features well, where as a linear regression model would not. In this case study we demonstrate the performance ability even with only a few features and almost all of them being highly correlated with each other.
# Random Forest is also used as an efficient way to investigate the importance of a set of features with a large data set. Consider random forest to be one of your first choices when building a decision tree, especially for multiclass classifications.

# %% [markdown]
# # Let's try this again without the age feature

# %%
df2 = df2.drop(['n_age'], axis=1)

# %% [markdown]
# **<font color='teal'> Print a covariance heatmap. </font>**

# %%
nominal.associations(df2, figsize=(15,15));

# %% [markdown]
# #### Our important features seem to be:
#
# State: 0.77
# City: 0.42
# Infection Case: 0.35
# Province: 0.28
# Sex: 0.06
# Contact Number: 0.0
#
#  The values have not changed since our last heatmap.

# %% [markdown]
# **<font color='teal'> Create dummy features for object type features. </font>**

# %%
df2.head()
# Out:
#       sex province         city  disease        infection_case  \
# 0    male    Seoul   Gangseo-gu        0       overseas inflow
# 1    male    Seoul  Jungnang-gu        0       overseas inflow
# 2    male    Seoul    Jongno-gu        0  contact with patient
# 3    male    Seoul      Mapo-gu        0       overseas inflow
# 4  female    Seoul  Seongbuk-gu        0  contact with patient
#
#    contact_number     state
# 0            75.0  released
# 1            31.0  released
# 2            17.0  released
# 3             9.0  released
# 4             2.0  released

# %%
df2 = pd.get_dummies(df2)

# %%
df2.head()
# Out:
#    disease  contact_number  sex_female  sex_male  sex_unknown  province_Busan  \
# 0        0            75.0           0         1            0               0
# 1        0            31.0           0         1            0               0
# 2        0            17.0           0         1            0               0
# 3        0             9.0           0         1            0               0
# 4        0             2.0           1         0            0               0
#
#    province_Chungcheongbuk-do  province_Chungcheongnam-do  province_Daegu  \
# 0                           0                           0               0
# 1                           0                           0               0
# 2                           0                           0               0
# 3                           0                           0               0
# 4                           0                           0               0
#
# ...

# %% [markdown]
# ### Split the data into test and train subsamples

# %%
from sklearn.model_selection import train_test_split

# dont forget to define your X and y

X = df2.drop(['disease'], axis=1)
y = df2['disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=1)

# %% [markdown]
# ### Scale data to prep for model creation

# %%
#scale data
from sklearn import preprocessing
import numpy as np
# build scaler based on training data and apply it to test data to then also scale the test data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,roc_auc_score
from sklearn.metrics import accuracy_score,log_loss
from matplotlib import pyplot

# %% [markdown]
# ### Fit Random Forest Classifier
# The fit model shows an overall accuracy of 80% which is great and indicates our model was effectively able to identify the status of a patients in the South Korea dataset.

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=300, random_state = 1,n_jobs=-1)
model_res = clf.fit(X_train_scaled, y_train)
y_pred = model_res.predict(X_test_scaled)
y_pred_prob = model_res.predict_proba(X_test_scaled)
lr_probs = y_pred_prob[:,1]
ac = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')
cm = confusion_matrix(y_test, y_pred)

print('Random Forest: Accuracy=%.3f' % (ac))

print('Random Forest: f1-score=%.3f' % (f1))
# Out:
# Random Forest: Accuracy=0.993
# Random Forest: f1-score=0.994

# %% [markdown]
# ### Create Confusion Matrix Plots
# Confusion matrices are great ways to review your model performance for a multi-class classification problem. Being able to identify which class the misclassified observations end up in is a great way to determine if you need to build additional features to improve your overall model. In the example below we plot a regular counts confusion matrix as well as a weighted percent confusion matrix. The percent confusion matrix is particulary helpful when you have unbalanced class sizes.

# %%
class_names=['isolated','released','missing','deceased'] # name  of classes

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
#plt.savefig('figures/RF_cm_multi_class.png')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
#plt.savefig('figures/RF_cm_proportion_multi_class.png', bbox_inches="tight")
plt.show()
# Out:
# Confusion matrix, without normalization
# [[438   2]
#  [  1   3]]
# Normalized confusion matrix
# [[1.   0.  ]
#  [0.25 0.75]]

# %% [markdown]
# ### Plot feature importances
# The random forest algorithm can be used as a regression or classification model. In either case it tends to be a bit of a black box, where understanding what's happening under the hood can be difficult. Plotting the feature importances is one way that you can gain a perspective on which features are driving the model predictions.

# %%
feature_importance = clf.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(10,10))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# 30

# %% [markdown]
# The popularity of random forest is primarily due to how well it performs in a multitude of data situations. It tends to handle highly correlated features well, where as a linear regression model would not. In this case study we demonstrate the performance ability even with only a few features and almost all of them being highly correlated with each other.
# Random Forest is also used as an efficient way to investigate the importance of a set of features with a large data set. Consider random forest to be one of your first choices when building a decision tree, especially for multiclass classifications.
